# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import matplotlib.pyplot as plt

# %%
# Función para descargar precios de cierre ajustados:
def get_adj_closes(tickers, start_date=None, end_date=None):
    # Fecha inicio por defecto (start_date='2010-01-01') y fecha fin por defecto (end_date=today)
    # Descargamos DataFrame con todos los datos
    closes = web.DataReader(name=tickers, data_source='yahoo', start=start_date, end=end_date)
    # Solo necesitamos los precios ajustados en el cierre
    closes = closes['Adj Close']
    # Se ordenan los índices de manera ascendente
    closes.sort_index(inplace=True)
    return closes

# %%
data=pd.read_excel('Equity.xlsx', columns=['TICKER'])
tickers=data['TICKER'].tolist()

# %%
hst= get_adj_closes(tickers,'2016-01-01','2021-05-20')

# %%
hst
# Out:
# Symbols           AAPL         AMZN         BK         BLK        BMY  \
# Date
# 2016-01-04   24.323219   636.989990  35.228973  291.023773  57.613514
# 2016-01-05   23.713696   633.789978  35.096767  291.775116  58.748077
# 2016-01-06   23.249626   632.650024  34.215393  288.455139  57.716663
# 2016-01-07   22.268383   607.940002  33.351627  275.847900  56.117958
# 2016-01-08   22.386133   607.049988  32.743477  268.902069  54.691162
# ...                ...          ...        ...         ...        ...
# 2021-05-14  127.449997  3222.899902  51.779999  856.869995  64.879997
# 2021-05-17  126.269997  3270.389893  52.090000  849.460022  65.459999
# 2021-05-18  124.849998  3232.280029  50.750000  840.140015  65.599998
# 2021-05-19  124.690002  3231.800049  50.860001  838.520020  65.550003
# 2021-05-20  127.309998  3247.679932  50.610001  844.880005  67.000000
#
# Symbols             C        COST         CRM         DIS          FB  ...  \
# Date                                                                   ...
# 2016-01-04  44.961174  141.298401   76.709999   97.155785  102.220001  ...
# 2016-01-05  44.723747  141.643829   77.050003   95.193428  102.730003  ...
# 2016-01-06  44.073032  140.332993   76.290001   94.683952  102.970001  ...
# 2016-01-07  41.821899  137.118118   74.300003   93.872604   97.919998  ...
# 2016-01-08  40.564423  134.717957   73.230003   93.636742   97.330002  ...
# ...               ...         ...         ...         ...         ...  ...
# 2021-05-14  76.559998  384.420013  217.660004  173.699997  315.940002  ...
# 2021-05-17  77.419998  383.959991  215.059998  170.080002  315.459991  ...
# 2021-05-18  76.620003  382.809998  214.330002  169.679993  309.959991  ...
# 2021-05-19  76.459999  379.660004  221.339996  169.270004  313.589996  ...
# 2021-05-20  76.199997  383.579987  223.779999  171.360001  318.609985  ...
#
# Symbols           NVDA        PFE          PG        QCOM        SBUX  \
# Date
# 2016-01-04   31.661398  24.622292   66.629204   41.914345   52.536762
# 2016-01-05   32.170021  24.799541   66.841728   41.094791   52.888458
# 2016-01-06   30.839788  24.360273   66.195602   40.676651   52.419544
# 2016-01-07   29.617151  24.198435   65.617455   38.585953   51.121002
# 2016-01-08   28.981380  23.890173   64.588730   38.368530   51.066895
# ...                ...        ...         ...         ...         ...
# 2021-05-14  569.719971  40.020000  138.009995  130.149994  111.199997
# 2021-05-17  566.619995  40.110001  137.729996  129.800003  110.980003
# 2021-05-18  560.630005  40.049999  136.320007  128.910004  111.070000
# 2021-05-19  562.630005  39.830002  136.600006  130.660004  109.669998
# 2016-01-06 -0.009714 -0.010227 -0.008906 -0.001467 -0.013198 -0.009076
# 2016-01-07 -0.008772 -0.052766 -0.025084 -0.016280 -0.019858 -0.005507
# 2016-01-08 -0.015802 -0.005651 -0.001059  0.000895 -0.012409 -0.009767
# 2016-01-11  0.009172  0.004132  0.020796  0.012150  0.014169  0.005783
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-14  0.002103  0.023635  0.006405  0.000931  0.014201 -0.002043
# 2021-05-17 -0.002031 -0.002693 -0.001980 -0.027356 -0.002206 -0.012861
# 2021-05-18 -0.010290 -0.006880  0.000811 -0.059768 -0.003849 -0.013204
# 2021-05-19  0.002052  0.013484 -0.012685 -0.020168 -0.004354 -0.004557
# 2021-05-20  0.010197  0.015040  0.015741  0.023209  0.008204 -0.002286
#
# Symbols          WMT       PGR
# Date
# 2016-01-05  0.023477  0.009275
# 2016-01-06  0.009963 -0.011205
# 2016-01-07  0.023022 -0.017211
# 2016-01-08 -0.023179 -0.014849
# 2016-01-11  0.010645  0.018446
# ...              ...       ...
# 2021-05-14  0.009217  0.009852
# 2021-05-17 -0.004526 -0.005055
# 2021-05-18  0.021511 -0.005458
# 2021-05-19  0.000070 -0.048130
# 2021-05-20  0.003517  0.010244
#
# [1354 rows x 31 columns]

# %%
ret_summary_a = pd.DataFrame(columns=['Mean', 'Volatility'], index=tickers)
ret_summary_a['Mean']=252*ret_cc.mean()
ret_summary_a['Volatility']=np.sqrt(252)*ret_cc.std()
ret_summary_a
# Out:
#            Mean  Volatility
# AAPL   0.308057    0.302076
# AMZN   0.303171    0.298933
# BK     0.067426    0.292678
# BLK    0.198360    0.288571
# BMY    0.028091    0.266720
# C      0.098187    0.372359
# COST   0.185868    0.211212
# CRM    0.199261    0.339764
# DIS    0.105611    0.276502
# FB     0.211583    0.330824
# GOOGL  0.206793    0.266306
# INTC   0.120046    0.339647
# JPM    0.199975    0.300020
# KHC   -0.053672    0.312044
# KO     0.079280    0.198994
# MA     0.258634    0.291094
# MDLZ   0.088083    0.230383
# MRK    0.107276    0.218542
# MS     0.212816    0.343725
# MSFT   0.297734    0.275213
# NKE    0.154742    0.280467
# NVDA   0.542648    0.471725
# PFE    0.090866    0.219839
# PG     0.135512    0.197991
# QCOM   0.214407    0.367456
# SBUX   0.139904    0.270335
# T      0.031651    0.229664
# V      0.210777    0.260141
# VZ     0.085073    0.188840
# WMT    0.179171    0.219427
# PGR    0.257134    0.238879

# %%
# Gráfico rendimiento esperado vs. volatilidad
# Puntos a graficar
x_points = ret_summary_a['Volatility'].values
y_points = ret_summary_a['Mean'].values
# Ventana para graficar
plt.figure(figsize=(16,12))
plt.grid()
# Graficar puntos
plt.plot(x_points,y_points,'or',ms=10)
# Etiquetas de los ejes
plt.xlabel('Volatilidad $\sigma$')
plt.ylabel('Rendimiento esperado $E[r]$')
# Etiquetas de cada valor
for i, txt in enumerate(tickers):
    plt.annotate(txt, (x_points[i], y_points[i]))

# %% [markdown]
# Precio objetivo en lugar de r esperado.
#
#
# -> Precio objetivo a un año
#
#
# Vol. implicita en mi x
#
#
# Option pricing como objetivo
